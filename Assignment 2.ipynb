# %%
def find_largest_of_three(num1, num2, num3):
    if (num1 >= num2) and (num1 >= num3):
        largest = num1
    elif (num2 >= num1) and (num2 >= num3):
        largest = num2
    else:
        largest = num3
        
    return largest

try:
    a = float(input("Enter the first number: "))
    b = float(input("Enter the second number: "))
    c = float(input("Enter the third number: "))

    result = find_largest_of_three(a, b, c)
    print(f"The largest number among {a}, {b}, and {c} is: {result}")

except ValueError:
    print("Please enter valid numbers.")
# Out:
# Enter the first number:  8768978768798
# Enter the second number:  36766545809
# Enter the third number:  787676457656757
# The largest number among 8768978768798.0, 36766545809.0, and 787676457656757.0 is: 787676457656757.0
